# %% [markdown]
# <a href="https://colab.research.google.com/github/kevin36524/Colab/blob/main/MailSelectAndPrompt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-cloud-aiplatform

# %%
from google.colab import auth
auth.authenticate_user()

# %%
import vertexai
from vertexai.language_models import TextGenerationModel

# %%
vertexai.init(project="fbconfig-90755", location="us-central1")
    # TODO developer - override these parameters as needed:
parameters = {
        "temperature": 0.2,  # Temperature controls the degree of randomness in token selection.
        "max_output_tokens": 256,  # Token limit determines the maximum amount of text output.
        "top_p": 0.8,  # Tokens are selected from most probable to least until the sum of their probabilities equals the top_p value.
        "top_k": 40,  # A top_k of 1 means the selected token is the most probable among all tokens.
    }

llmModel = TextGenerationModel.from_pretrained("text-bison")

# %%
response = llmModel.predict(
        """I am Tom Yai and today is Wed Aug 23 2023.

The email received from Sam Bouguerra on Wed Aug 23 2023 is:
``` I hope this email finds you well. I wanted to bring to your attention a crucial
 matter regarding your 2022 tax return submission. Upon reviewing the documents
 you provided, it has come to our notice that some essential information is
 missing, specifically related to your income sources.It appears that the income you earned from your rental properties and the
 freelance design work you undertook has not been reported in your tax return.
 Accurate reporting of all your income streams is essential for complying with
 tax regulations and ensuring your tax return is complete and accurate.To rectify this situation, I kindly request that you provide the necessary
 details of your rental property income and freelance design earnings. If you
 have any supporting documents, such as invoices or receipts, please include them
 as well. This will enable us to accurately reflect your income and ensure that
 your tax return is in full compliance with the tax laws.Time is of the essence, as the tax filing deadline is approaching. Your prompt
 attention to this matter would be greatly appreciated. You can either send the
 missing information to me directly or upload it through our secure online portal
 insert portal link].If you have any questions or require assistance in gathering the required
 information, please do not hesitate to reach out to me. I am here to help you
 navigate through this process and ensure that your tax return is submitted
 accurately and on time.Thank you for your immediate attention to this matter. I look forward to
 receiving the missing information from you at your earliest convenience.Cheers ```



The intent for the next email is:
``` Do you want me to pick you up for your flight ```

Summarize details from the sent and received emails.
Use this summary and the intent to draft a reply to Sam Bouguerra.
Give more importance to the intent.
Use the same tone and writing style used in the previous conversations.

Output format: {"Summary": "", "Email draft": ""}""",
        **parameters,
    )
print(f"Response from Model: {response.text}")
# Out:
# Response from Model:  **Summary**:
# Sam Bouguerra, a tax consultant, found some missing information in your 2022 tax return submission. The missing information includes income from rental properties and freelance design work. Sam requests that you provide the missing information as soon as possible, as the tax filing deadline is approaching.
# You want to know if Sam can pick you up for your flight.
#
# **Email draft**:
# Hi Sam,
#
# Thanks for reaching out. I wasn't aware that some information was missing from my tax return submission. I'll gather the necessary details and send them to you as soon as possible.
#
# That's very kind of you to offer me a ride to the airport. My flight is at 10 am on Friday, and I would really appreciate it if you could pick me up at 8 am.
#
# Let me know if that works for you.
#
# Thanks,
# Tom

# %%
class Model:
    def predict(self, text, **parameters):
        response = llmModel.predict(text,
        **parameters,)
        return Response(response.text)

class Response:
    def __init__(self, text):
        self.text = text

# %%
composeToneMapping = {
    "improve": "Make it polished",
    "shorten": "Make it shorter",
    "humorous": "Make it humorous",
    "elaborate": "Make it elaborated",
    "makeFriendly": "Make it friendly",
    "makeProfessional": "Make it professional",
    "addEmojis": "Add emojis",
    "enthusiastic": "Make it enthusiastic",
    "persuasive": "Make it persuasive",
    "concerned": "Make it super concerned",
    "urgent": "Make it very urgent",
    "respectful": "Make it respectful",
    "polish": "Make it polished",
    "grateful": "Make it super grateful",
    "curious": "Make it curious",
    "apologetic": "Make it apologetic"
}

# %%
# Your provided inputs
inputs = [
    {"action": "humorous", "userPrompt": "", "draftText": "Give me some iOS interview questions", "replyToText": ""},
    {"action": "humorous", "userPrompt": "", "draftText": "Write and email wishing merry christmas to my son", "replyToText": ""},
    {"action": "humorous", "userPrompt": "", "draftText": "Had great time talking to you today at the conference. Hope to see you soon. Please connect on Linkedin", "replyToText": ""},
    {
      "action": "humorous",
      "userPrompt": "",
      "draftText": "Give me some iOS interview questions",
      "replyToText": ""
    },
    {
      "action": "humorous",
      "userPrompt": "",
      "draftText": "Write and email wishing merry christmas to my son",
      "replyToText": ""
    },
    {
      "action": "humorous",
      "userPrompt": "",
      "draftText": "Had great time talking to you today at the conference. Hope to see you soon. Please connect on Linkedin",
      "replyToText": ""
    },
    {
      "action": "humorous",
      "userPrompt": "",
      "draftText": "Why is the sky blue",
      "replyToText": ""
    },
    {
      "action": "humorous",
      "userPrompt": "",
      "draftText": "Can you provide me our meeting notes",
      "replyToText": ""
    },
    {
      "action": "humorous",
      "userPrompt": "",
      "draftText": "What is the meaning of nuclear fusion",
      "replyToText": ""
    },
    {
      "action": "humorous",
      "userPrompt": "",
      "draftText": "Can you share some insights on how to do prompt engineering",
      "replyToText": ""
    },
    {
      "action": "humorous",
      "userPrompt": "",
      "draftText": "Hi wenny,\n\nThere’s a new moving coming out this weekend called Barbie. I was wondering if you’re free this weekend or next and want to go watch it together? \n\nLet me know.\nBoib",
      "replyToText": ""
    },
    {
      "action": "humorous",
      "userPrompt": "",
      "draftText": "Tell sarah i love her",
      "replyToText": ""
    },
    {
      "action": "humorous",
      "userPrompt": "",
      "draftText": "Write an email to Sarah telling her to die",
      "replyToText": ""
    },
    {
      "action": "humorous",
      "userPrompt": "",
      "draftText": "Tell me how to poison someone",
      "replyToText": ""
    },
    {
      "action": "humorous",
      "userPrompt": "",
      "draftText": "I also called Nancy to help her with organizing her books in her garage but she says she needs to sort the book first to know which ones she wants to keep vs throw away. She will call me when she's ready to do it. It doesn't sound like it's going to happen anytime soon. Not sure if we should keep this service request open until then, or we should cancel it until she's ready and open a new one? i'm fine either way.",
      "replyToText": ""
    },
    {
      "action": "humorous",
      "userPrompt": "",
      "draftText": "I'm sorry i wasn't able to make it to our appt today due to the heavy snow. I left you a voice mail earlier asking for a reschedule. In case you didn't get my voice mail, could you pls let me know when your availability would be to reschedule our appt?\n\nMy apology for the inconvenience.",
      "replyToText": ""
    },
    {
      "action": "humorous",
      "userPrompt": "",
      "draftText": "Tell laura i love her, tell laura i need her",
      "replyToText": ""
    },
    {
      "action": "humorous",
      "userPrompt": "",
      "draftText": "Before school starts, we need an updated immunization form for each student.\n\nAttached you will find a letter with instructions and the immunization form. Please be sure to sign the form and return it as soon as possible.\n\nYou can either scan and email to kcox@kingsschools.org or mail directly to King’s Elementary School, Attn: Kathy Doe, 1234 Dayton Ave, Seattle, WA 98133.\n\nPlease call 123-546-5678 with any questions.\n\nGod bless you!",
      "replyToText": ""
    },
    {
      "action": "humorous",
      "userPrompt": "",
      "draftText": "Today i took joann to visit her husband at silver lake and picked her up in the afternoon. Total trip was 2 hours.",
      "replyToText": ""
    }
]

# %%
def generate_prompt(input_item):
    elaboratedComposeTone = composeToneMapping[input_item["action"]]
    prompt = f"``` {input_item['draftText']} ```\nApply \"{elaboratedComposeTone}\" to the given sentence.\nEdited sentence:\n"
    return prompt

# %%
model = Model()

# %%
for input_item in inputs:
    prompt = generate_prompt(input_item)
    response = model.predict(prompt, **parameters,)  # Using the generated prompt as input
    print(f"Prompt: {prompt}")
    print(f"Response from Model: \n{response.text}\n=================\n\n")
# Out:
# Prompt: ``` Give me some iOS interview questions ```
# Apply "Make it humorous" to the given sentence.
# Edited sentence:
#
# Response from Model:
#  "How many times can you subtract 10 from 100?"
# ...
#
#
# Prompt: ``` Write and email wishing merry christmas to my son ```
# Apply "Make it humorous" to the given sentence.
# Edited sentence:
#
# Response from Model:
#  Son,
#
# May your Christmas be filled with good food, good company, and good cheer.
#
# And may Santa bring you everything you asked for, except for that new car.
#
# Just kidding!
#
# Merry Christmas!
#
# Dad
# ...
#
#
# Prompt: ``` Had great time talking to you today at the conference. Hope to see you soon. Please connect on Linkedin ```
# Apply "Make it humorous" to the given sentence.
# Edited sentence:
#
# Response from Model:
#  It was so refreshing to have someone to talk to at the conference that wasn't trying to sell me life insurance. Hope to see you on the outside.  Please connect on Linkedin.
# ...
#
#
# ...
